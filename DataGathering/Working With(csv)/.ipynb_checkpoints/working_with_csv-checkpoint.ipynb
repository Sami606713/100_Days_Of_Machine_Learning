# %% [markdown]
# # Load the lobraries and dataset

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read_csv

# %%
salaries=pd.read_csv('salaries.csv')
salaries.head(2)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   90000             USD          90000                 AE             0
# 1  180500             USD         180500                 US             0
#
#   company_location company_size
# 0               AE            L
# 1               US            M

# %% [markdown]
# # use_col
# 1. **It is use to get the specific columns**

# %%
pd.read_csv('salaries.csv',usecols=['work_year','job_title','salary_in_usd'])
# Out:
#        work_year                  job_title  salary_in_usd
# 0           2024                AI Engineer          90000
# 1           2024  Machine Learning Engineer         180500
# 2           2024  Machine Learning Engineer          96200
# 3           2024  Machine Learning Engineer         235000
# 4           2024  Machine Learning Engineer         175000
# ...          ...                        ...            ...
# 13967       2020             Data Scientist         412000
# 13968       2021   Principal Data Scientist         151000
# 13969       2020             Data Scientist         105000
# 13970       2020      Business Data Analyst         100000
# 13971       2021       Data Science Manager          94665
#
# [13972 rows x 3 columns]

# %% [markdown]
# # skiprows
# 1. **It is use to skip the any rows**

# %%
pd.read_csv('salaries.csv',skiprows=[0,1])
# Out:
#        2024  SE  FT        Machine Learning Engineer   180500  USD  180500.1  \
# 0      2024  SE  FT        Machine Learning Engineer    96200  USD     96200
# 1      2024  SE  FT        Machine Learning Engineer   235000  USD    235000
# 2      2024  SE  FT        Machine Learning Engineer   175000  USD    175000
# 3      2024  MI  FT  Business Intelligence Developer    95413  USD     95413
# 4      2024  MI  FT  Business Intelligence Developer    70692  USD     70692
# ...     ...  ..  ..                              ...      ...  ...       ...
# 13965  2020  SE  FT                   Data Scientist   412000  USD    412000
# 13966  2021  MI  FT         Principal Data Scientist   151000  USD    151000
# 13967  2020  EN  FT                   Data Scientist   105000  USD    105000
# 13968  2020  EN  CT            Business Data Analyst   100000  USD    100000
# 13969  2021  SE  FT             Data Science Manager  7000000  INR     94665
#
#        US    0 US.1  M
# ...

# %% [markdown]
# **Now skip the even rows**

# %%
pd.read_csv('salaries.csv',skiprows=[i for i in range(10) if i%2==0])
# Out:
#        2024  SE  FT                      AI Engineer    90000  USD  90000.1  \
# 0      2024  SE  FT        Machine Learning Engineer    96200  USD    96200
# 1      2024  SE  FT        Machine Learning Engineer   175000  USD   175000
# 2      2024  MI  FT  Business Intelligence Developer    70692  USD    70692
# 3      2024  SE  FT                    Data Engineer    48000  USD    48000
# 4      2024  SE  FT                   Data Scientist   222300  USD   222300
# ...     ...  ..  ..                              ...      ...  ...      ...
# 13962  2020  SE  FT                   Data Scientist   412000  USD   412000
# 13963  2021  MI  FT         Principal Data Scientist   151000  USD   151000
# 13964  2020  EN  FT                   Data Scientist   105000  USD   105000
# 13965  2020  EN  CT            Business Data Analyst   100000  USD   100000
# 13966  2021  SE  FT             Data Science Manager  7000000  INR    94665
#
#        AE    0 AE.1  L
# 0      US    0   US  M
# ...

# %% [markdown]
# # Sep keyword
# 1. It is used to saperate each column with specific character

# %%
pd.read_csv('salaries.csv',sep=",")
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT  Machine Learning Engineer
# 2           2024               SE              FT  Machine Learning Engineer
# 3           2024               SE              FT  Machine Learning Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020               SE              FT             Data Scientist
# 13968       2021               MI              FT   Principal Data Scientist
# 13969       2020               EN              FT             Data Scientist
# 13970       2020               EN              CT      Business Data Analyst
# 13971       2021               SE              FT       Data Science Manager
#
# ...

# %% [markdown]
# # index_col
# 1. It is used to set any column as index

# %%
pd.read_csv('salaries.csv',index_col='work_year')
# Out:
#           experience_level employment_type                  job_title  \
# work_year
# 2024                    SE              FT                AI Engineer
# 2024                    SE              FT  Machine Learning Engineer
# 2024                    SE              FT  Machine Learning Engineer
# 2024                    SE              FT  Machine Learning Engineer
# 2024                    SE              FT  Machine Learning Engineer
# ...                    ...             ...                        ...
# 2020                    SE              FT             Data Scientist
# 2021                    MI              FT   Principal Data Scientist
# 2020                    EN              FT             Data Scientist
# 2020                    EN              CT      Business Data Analyst
# 2021                    SE              FT       Data Science Manager
#
#             salary salary_currency  salary_in_usd employee_residence  \
# work_year
# ...

# %% [markdown]
# # skip_blank_lines
# 1. It is used to skip the bad lines

# %%
pd.read_csv('salaries.csv',skip_blank_lines=False)
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT  Machine Learning Engineer
# 2           2024               SE              FT  Machine Learning Engineer
# 3           2024               SE              FT  Machine Learning Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020               SE              FT             Data Scientist
# 13968       2021               MI              FT   Principal Data Scientist
# 13969       2020               EN              FT             Data Scientist
# 13970       2020               EN              CT      Business Data Analyst
# 13971       2021               SE              FT       Data Science Manager
#
# ...

# %% [markdown]
# # chunksize
# 1. It is used to load the data in the form of chunk

# %%
chunk_df=pd.read_csv('salaries.csv',chunksize=1000)
for i in chunk_df:
    print(i.shape)
# Out:
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (1000, 11)
# (972, 11)

# %% [markdown]
# # nrows
# 1. It is used to load limited rows

# %%
pd.read_csv('salaries.csv',nrows=500)
# Out:
#      work_year experience_level employment_type                  job_title  \
# 0         2024               SE              FT                AI Engineer
# 1         2024               SE              FT  Machine Learning Engineer
# 2         2024               SE              FT  Machine Learning Engineer
# 3         2024               SE              FT  Machine Learning Engineer
# 4         2024               SE              FT  Machine Learning Engineer
# ..         ...              ...             ...                        ...
# 495       2024               MI              FT             Data Scientist
# 496       2024               MI              FT  Machine Learning Engineer
# 497       2024               MI              FT  Machine Learning Engineer
# 498       2024               SE              FT               Data Analyst
# 499       2024               SE              FT               Data Analyst
#
# ...

# %% [markdown]
# # header
# 1. It is used to set any rows as header

# %%
pd.read_csv('salaries.csv',header=1)
# Out:
#        2024  SE  FT                      AI Engineer    90000  USD  90000.1  \
# 0      2024  SE  FT        Machine Learning Engineer   180500  USD   180500
# 1      2024  SE  FT        Machine Learning Engineer    96200  USD    96200
# 2      2024  SE  FT        Machine Learning Engineer   235000  USD   235000
# 3      2024  SE  FT        Machine Learning Engineer   175000  USD   175000
# 4      2024  MI  FT  Business Intelligence Developer    95413  USD    95413
# ...     ...  ..  ..                              ...      ...  ...      ...
# 13966  2020  SE  FT                   Data Scientist   412000  USD   412000
# 13967  2021  MI  FT         Principal Data Scientist   151000  USD   151000
# 13968  2020  EN  FT                   Data Scientist   105000  USD   105000
# 13969  2020  EN  CT            Business Data Analyst   100000  USD   100000
# 13970  2021  SE  FT             Data Science Manager  7000000  INR    94665
#
#        AE    0 AE.1  L
# 0      US    0   US  M
# ...

# %% [markdown]
# # encoding=None
# 1. It is used if get the `encoding error` some encoding parameter are `utf-8 latin-1`

# %%
pd.read_csv('salaries.csv',encoding='utf-8')
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT  Machine Learning Engineer
# 2           2024               SE              FT  Machine Learning Engineer
# 3           2024               SE              FT  Machine Learning Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020               SE              FT             Data Scientist
# 13968       2021               MI              FT   Principal Data Scientist
# 13969       2020               EN              FT             Data Scientist
# 13970       2020               EN              CT      Business Data Analyst
# 13971       2021               SE              FT       Data Science Manager
#
# ...

# %% [markdown]
# # NA-Values
# 1. It is used to treat any value as NA

# %%
pd.read_csv('salaries.csv',na_values='Data Scientist')
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT  Machine Learning Engineer
# 2           2024               SE              FT  Machine Learning Engineer
# 3           2024               SE              FT  Machine Learning Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020               SE              FT                        NaN
# 13968       2021               MI              FT   Principal Data Scientist
# 13969       2020               EN              FT                        NaN
# 13970       2020               EN              CT      Business Data Analyst
# 13971       2021               SE              FT       Data Science Manager
#
# ...
